# %% [markdown]
# # Working with APIs

# %% [markdown]
# API stands for Application programming interface<br>
# APIs are a way for applications to talk to eachother<br>
# In python we use the requests package to handle the connection<br>
# <small><strong>Note: It is requests with an s not request(this is a different package)</strong></small><br>
# Most API's communicate with data in the form of JSON<br>
# JSON stands for JavaScript Object Notation

# %%
#import the packages we need:
import requests, json

# %% [markdown]
# We will be connecting to the Ergast F1 Racer API today:
# http://ergast.com/mrd/
#
# to view JSON data nicely in the Chrome browser install the extension JSONview

# %%
help(requests)
# Out:
# Help on package requests:
#
# NAME
#     requests
#
# DESCRIPTION
#     Requests HTTP Library
#     ~~~~~~~~~~~~~~~~~~~~~
#
#     Requests is an HTTP library, written in Python, for human beings.
#     Basic GET usage:
#
#        >>> import requests
#        >>> r = requests.get('https://www.python.org')
#        >>> r.status_code
#        200
#        >>> b'Python is a programming language' in r.content
#        True
#
#     ... or POST:
#
#        >>> payload = dict(key1='value1', key2='value2')
#        >>> r = requests.post('https://httpbin.org/post', data=payload)
#        >>> print(r.text)
#        {
#          ...
#          "form": {
#            "key1": "value1",
#            "key2": "value2"
#          },
#          ...
#        }
#
#     The other HTTP methods are supported - see `requests.api`. Full documentation
#     is at <https://requests.readthedocs.io>.
#
#     :copyright: (c) 2017 by Kenneth Reitz.
#     :license: Apache 2.0, see LICENSE for more details.
#
# ...

# %%
url = "http://ergast.com/api/f1/2008/5/driverStandings.json"

# %%
#response object
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#check and make sure we got a successful response from the API
print(response.status_code)
response.ok
# Out:
# 200
# True

# %%
print(response.json)
# Out:
# <bound method Response.json of <Response [200]>>

# %%
#view the response as a JSON
response.json()
# Out:
# {'MRData': {'xmlns': 'http://ergast.com/mrd/1.5',
#   'series': 'f1',
#   'url': 'http://ergast.com/api/f1/2008/5/driverstandings.json',
#   'limit': '30',
#   'offset': '0',
#   'total': '22',
#   'StandingsTable': {'season': '2008',
#    'round': '5',
#    'StandingsLists': [{'season': '2008',
#      'round': '5',
#      'DriverStandings': [{'position': '1',
#        'positionText': '1',
#        'points': '35',
#        'wins': '2',
#        'Driver': {'driverId': 'raikkonen',
#         'permanentNumber': '7',
#         'code': 'RAI',
#         'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#         'givenName': 'Kimi',
#         'familyName': 'Räikkönen',
#         'dateOfBirth': '1979-10-17',
#         'nationality': 'Finnish'},
#        'Constructors': [{'constructorId': 'ferrari',
#          'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#          'name': 'Ferrari',
#          'nationality': 'Italian'}]},
#       {'position': '2',
# ...

# %%
print(type(response.json()))
# Out:
# <class 'dict'>

# %%
# We only want the Driver Standings
data = response.json()["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"]
data
# Out:
# [{'position': '1',
#   'positionText': '1',
#   'points': '35',
#   'wins': '2',
#   'Driver': {'driverId': 'raikkonen',
#    'permanentNumber': '7',
#    'code': 'RAI',
#    'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#    'givenName': 'Kimi',
#    'familyName': 'Räikkönen',
#    'dateOfBirth': '1979-10-17',
#    'nationality': 'Finnish'},
#   'Constructors': [{'constructorId': 'ferrari',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#     'name': 'Ferrari',
#     'nationality': 'Italian'}]},
#  {'position': '2',
#   'positionText': '2',
#   'points': '28',
#   'wins': '2',
#   'Driver': {'driverId': 'massa',
#    'permanentNumber': '19',
#    'code': 'MAS',
#    'url': 'http://en.wikipedia.org/wiki/Felipe_Massa',
#    'givenName': 'Felipe',
#    'familyName': 'Massa',
#    'dateOfBirth': '1981-04-25',
#    'nationality': 'Brazilian'},
#   'Constructors': [{'constructorId': 'ferrari',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
# ...

# %%
print(type(data))
# Out:
# <class 'list'>

# %%
data[0]
# Out:
# {'position': '1',
#  'positionText': '1',
#  'points': '35',
#  'wins': '2',
#  'Driver': {'driverId': 'raikkonen',
#   'permanentNumber': '7',
#   'code': 'RAI',
#   'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#   'givenName': 'Kimi',
#   'familyName': 'Räikkönen',
#   'dateOfBirth': '1979-10-17',
#   'nationality': 'Finnish'},
#  'Constructors': [{'constructorId': 'ferrari',
#    'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#    'name': 'Ferrari',
#    'nationality': 'Italian'}]}

# %%
def get_racer_info(data):
    new_data=[]
    for racer in data:
        racer_dict={}
        racer_name = f"{racer['Driver']['givenName']} {racer['Driver']['familyName']}"
        
        racer_dict[racer_name]={
            'first_name':racer['Driver']['givenName'],
            'last_name':racer['Driver']['familyName'],
            'position':racer['position'],
            'wins':racer['wins'],
            'DOB':racer['Driver']['dateOfBirth'],
            'nationality':racer['Driver']['nationality'],
            'contructor':racer['Constructors'][0]['name']
        }
        new_data.append(racer_dict)
    return new_data

get_racer_info(data)
# Out:
# [{'Kimi Räikkönen': {'first_name': 'Kimi',
#    'last_name': 'Räikkönen',
#    'position': '1',
#    'wins': '2',
#    'DOB': '1979-10-17',
#    'nationality': 'Finnish',
#    'contructor': 'Ferrari'}},
#  {'Felipe Massa': {'first_name': 'Felipe',
#    'last_name': 'Massa',
#    'position': '2',
#    'wins': '2',
#    'DOB': '1981-04-25',
#    'nationality': 'Brazilian',
#    'contructor': 'Ferrari'}},
#  {'Lewis Hamilton': {'first_name': 'Lewis',
#    'last_name': 'Hamilton',
#    'position': '3',
#    'wins': '1',
#    'DOB': '1985-01-07',
#    'nationality': 'British',
#    'contructor': 'McLaren'}},
#  {'Robert Kubica': {'first_name': 'Robert',
#    'last_name': 'Kubica',
#    'position': '4',
#    'wins': '0',
#    'DOB': '1984-12-07',
#    'nationality': 'Polish',
#    'contructor': 'BMW Sauber'}},
#  {'Nick Heidfeld': {'first_name': 'Nick',
#    'last_name': 'Heidfeld',
#    'position': '5',
#    'wins': '0',
#    'DOB': '1977-05-10',
#    'nationality': 'German',
# ...

# %%
def get_driver_info_by_year_and_round(year,r):
    url =

# %%
def get_driver_info_by_year_and_round(year,r):
    url = f"http://ergast.com/api/f1/{year}/{r}/driverStandings.json"
    response = requests.get(url)
#     if not response.ok:
    if not response.json()["MRData"]["StandingsTable"]["StandingsLists"]:
        return "We had an error loading your data likely the year or round is not in the database"
    data = response.json()["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"]
    return get_racer_info(data)

get_driver_info_by_year_and_round(2025,3)
# Out:
# 'We had an error loading your data likely the year or round is not in the database'

# %% [markdown]
# # <strong>Homework</strong>
# check out this Pokemon API https://pokeapi.co/
# Use the requests package to connect to this API and get and store data for 5 different pokemon.
# Get the pokemons: name, atleast one ability's name, base_experience, and the URL for its sprite (an image that shows up on screen) for the 'front_shiny'

# %%
url0 = "https://pokeapi.co/api/v2/pokemon/jigglypuff"
poke0 = requests.get(url0)
print(poke0)

url1 = "https://pokeapi.co/api/v2/pokemon/charmander"
poke1 = requests.get(url1)
print(poke1)

url2 = "https://pokeapi.co/api/v2/pokemon/pikachu"
poke2 = requests.get(url2)
print(poke2)

url3 = "https://pokeapi.co/api/v2/pokemon/lucario"
poke3 = requests.get(url3)
print(poke3)

url4 = "https://pokeapi.co/api/v2/pokemon/gyarados"
poke4 = requests.get(url4)
print(poke4)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
print(poke0.status_code)
# Out:
# 200

# %%
#J-Puff

name0 = poke0.json()["forms"][0]

ability0 = poke0.json()["abilities"][2]

xp0 = poke0.json()["base_experience"]

image0 = poke0.json()["sprites"]["front_shiny"]

print(name0)
print(ability0)
print(xp0)
print(image0)
# Out:
# {'name': 'jigglypuff', 'url': 'https://pokeapi.co/api/v2/pokemon-form/39/'}
# {'ability': {'name': 'friend-guard', 'url': 'https://pokeapi.co/api/v2/ability/132/'}, 'is_hidden': True, 'slot': 3}
# 95
# https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/39.png

# %%
#Char Lizard

name1 = poke1.json()["forms"][0]

ability1 = poke1.json()["abilities"][1]

xp1 = poke1.json()["base_experience"]

image1 = poke1.json()["sprites"]["front_shiny"]

print(name1)
print(ability1)
print(xp1)
print(image1)
# Out:
# {'name': 'charmander', 'url': 'https://pokeapi.co/api/v2/pokemon-form/4/'}
# {'ability': {'name': 'solar-power', 'url': 'https://pokeapi.co/api/v2/ability/94/'}, 'is_hidden': True, 'slot': 3}
# 62
# https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/4.png

# %%
#Pika

name2 = poke2.json()["forms"][0]

ability2 = poke2.json()["abilities"][1]

xp2 = poke2.json()["base_experience"]

image2 = poke2.json()["sprites"]["front_shiny"]

print(name2)
print(ability2)
print(xp2)
print(image2)
# Out:
# {'name': 'pikachu', 'url': 'https://pokeapi.co/api/v2/pokemon-form/25/'}
# {'ability': {'name': 'lightning-rod', 'url': 'https://pokeapi.co/api/v2/ability/31/'}, 'is_hidden': True, 'slot': 3}
# 112
# https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/25.png

# %%
#Lucario

name3 = poke3.json()["forms"][0]

ability3 = poke3.json()["abilities"][2]

xp3 = poke3.json()["base_experience"]

image3 = poke3.json()["sprites"]["front_shiny"]

print(name3)
print(ability3)
print(xp3)
print(image3)
# Out:
# {'name': 'lucario', 'url': 'https://pokeapi.co/api/v2/pokemon-form/448/'}
# {'ability': {'name': 'justified', 'url': 'https://pokeapi.co/api/v2/ability/154/'}, 'is_hidden': True, 'slot': 3}
# 184
# https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/448.png

# %%
#Water Lizard

name4 = poke4.json()["forms"][0]

ability4 = poke4.json()["abilities"][1]

xp4 = poke4.json()["base_experience"]

image4 = poke4.json()["sprites"]["front_shiny"]

print(name4)
print(ability4)
print(xp4)
print(image4)
# Out:
# {'name': 'gyarados', 'url': 'https://pokeapi.co/api/v2/pokemon-form/130/'}
# {'ability': {'name': 'moxie', 'url': 'https://pokeapi.co/api/v2/ability/153/'}, 'is_hidden': True, 'slot': 3}
# 189
# https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/130.png
